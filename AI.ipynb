# %%
ai-analytics-assistant

# %%
import streamlit as st
import os
from openai import OpenAI
import pandas as pd

st.set_page_config(page_title="AI Data Analytics Assistant")

st.title("📊 Bharath's AI Data Analytics Assistant")

api_key = os.getenv("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")

from openai import OpenAI
import os

client = OpenAI(api_key="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")



def ask_ai(question):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are an expert Data Analyst. Explain step-by-step clearly."},
            {"role": "user", "content": question}
        ]
    )
    return response.choices[0].message.content

question = st.text_area("Ask any Data Analytics question:")

if st.button("Get Answer"):
    if question:
        answer = ask_ai(question)
        st.write(answer)

st.divider()

uploaded_file = st.file_uploader("Upload CSV for Analysis", type=["csv"])

if uploaded_file:
    df = pd.read_csv(uploaded_file)
    st.write("Preview of Data:")
    st.dataframe(df.head())
# Out:
# 2026-02-17 19:18:28.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:28.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:28.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:29.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:29.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:29.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:29.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 19:18:29.211 Session state does not function when running a script without `streamlit run`
# ...

# %% [markdown]
# # AI Data Analytics Assistant
#
# This project is an AI-powered assistant that:
# - Solves complex Data Analytics problems
# - Explains ML concepts
# - Suggests data cleaning steps
# - Analyzes uploaded CSV files
#
# Built using:
# - Python
# - Streamlit
# - OpenAI API
# - Pandas
